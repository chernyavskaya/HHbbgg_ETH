# %%
import pandas as pd
import numpy as np
from numpy.random import shuffle

# %%
data = pd.read_hdf("/scratch/nchernya/HHbbgg/ttbar_full_hd5/ttbar_full_jobs_RegressionPerJet_heppy_energyRings_forTraining_con120130_full.hd5",colums=None)

# %%
data
# Out:
#              Jet_pt   Jet_eta  Jet_mcFlavour    Jet_mcPt        rho  \
# 0         72.566414 -1.387692           -5.0   80.549110  13.583253
# 1         44.815495  0.029537            5.0   44.617207  17.448395
# 2         33.550144 -2.421322           -5.0   28.538713  17.448395
# 3        120.235657  0.981299           -5.0  162.908142   7.596349
# 4         92.927734  0.573715            5.0   85.854988   7.596349
# 5         76.363579  0.262529           -5.0  116.045044  15.298316
# 6         75.890228  2.017260            5.0   88.752586   8.021218
# 7         27.909719  0.136694           -5.0   29.208546   8.021218
# 8        133.339218  1.887084            5.0  143.557693  11.732431
# 9         84.501389 -2.209843           -5.0   67.954720  11.732431
# 10       171.718521  0.347664           -5.0  177.433182  12.510054
# 11        61.720406  0.884905            5.0   81.872223  12.510054
# 12       111.989311 -0.728873            5.0  100.357910  14.444227
# ...

# %%
df = data.sample(frac=1)
df
# Out:
#              Jet_pt   Jet_eta  Jet_mcFlavour    Jet_mcPt        rho  \
# 4872386   59.122608 -0.734958            5.0   53.628754   9.186208
# 6118486   46.896641 -0.743726            5.0   50.457195   9.457822
# 182414   185.631897 -0.529153           -5.0  184.367401  11.446676
# 6681343   65.383972  1.268759            5.0  104.613655  15.788078
# 58215     29.082500  0.804304           -5.0   22.352098  19.850330
# 3137487   38.884823 -2.364983           -5.0   33.264503  12.404602
# 5399438   53.811886  1.495613           -5.0   54.148617  10.315295
# 5287115   29.013176  1.555135            5.0   38.157719  22.107180
# 4601697  151.549774  0.009834           -5.0  179.748886  20.658661
# 5965543   59.290398  1.358062            5.0   69.565918   7.497060
# 2550138  149.789505 -0.718624           -5.0  171.753418  10.685512
# 6701830   87.342628  1.561754           -5.0   91.600555  12.324209
# 6496237  246.209778  0.220946            5.0  315.649933  20.564329
# ...

# %%
x1 = np.random.uniform(size=5)
x2 = np.random.uniform(size=5)
y = np.random.uniform(size=5)
df = pd.DataFrame({"x1" : x1, "x2" : x2, "y" : y})

# %%
df
# Out:
#          x1        x2         y
# 0  0.559848  0.522957  0.684363
# 1  0.666682  0.649671  0.203462
# 2  0.501939  0.425009  0.658211
# 3  0.504510  0.954037  0.716340
# 4  0.339701  0.984887  0.385465

# %%
df2 = df.sample(frac=1)
df3 = df.sample(frac=1)

# %%
df2
# Out:
#          x1        x2         y
# 3  0.457966  0.392138  0.179292
# 0  0.205521  0.241903  0.507167
# 4  0.095045  0.044485  0.157574
# 2  0.454745  0.355810  0.867873
# 1  0.674958  0.088033  0.055751

# %%
df3
# Out:
#          x1        x2         y
# 0  0.559848  0.522957  0.684363
# 2  0.501939  0.425009  0.658211
# 4  0.339701  0.984887  0.385465
# 1  0.666682  0.649671  0.203462
# 3  0.504510  0.954037  0.716340

# %%
df
# Out:
#          x1        x2         y
# 0  0.559848  0.522957  0.684363
# 1  0.666682  0.649671  0.203462
# 2  0.501939  0.425009  0.658211
# 3  0.504510  0.954037  0.716340
# 4  0.339701  0.984887  0.385465

# %%
idx = np.random.permutation(len(df))
df.iloc[idx][['x1','x2']]
# Out:
#          x1        x2
# 4  0.095045  0.044485
# 2  0.454745  0.355810
# 3  0.457966  0.392138
# 1  0.674958  0.088033
# 0  0.205521  0.241903

# %%
df
# Out:
#          x1        x2         y
# 0  0.205521  0.241903  0.507167
# 1  0.674958  0.088033  0.055751
# 2  0.454745  0.355810  0.867873
# 3  0.457966  0.392138  0.179292
# 4  0.095045  0.044485  0.157574

# %%
print np.random.permutation(len(df))
# Out:
# [0 3 4 2 1]

# %%
np.random.permutation(len(df))
# Out:
# array([4, 1, 0, 3, 2])

# %%
df
# Out:
#          x1        x2         y
# 0  0.559848  0.522957  0.684363
# 1  0.666682  0.649671  0.203462
# 2  0.501939  0.425009  0.658211
# 3  0.504510  0.954037  0.716340
# 4  0.339701  0.984887  0.385465

# %%
df.set_index(np.random.permutation(df.index),inplace=True)
df.sort_index(inplace=True)

# %%
df
# Out:
#          x1        x2         y
# 0  0.666682  0.649671  0.203462
# 1  0.559848  0.522957  0.684363
# 2  0.339701  0.984887  0.385465
# 3  0.501939  0.425009  0.658211
# 4  0.504510  0.954037  0.716340

# %%
X_df = df['x1']

# %%
X_df
# Out:
# 4    0.559848
# 0    0.666682
# 3    0.501939
# 1    0.504510
# 2    0.339701
# Name: x1, dtype: float64

# %%
X_df.iloc[0:2]
# Out:
# 4    0.559848
# 0    0.666682
# Name: x1, dtype: float64

# %%
X_df
# Out:
# 4    0.559848
# 0    0.666682
# 3    0.501939
# 1    0.504510
# 2    0.339701
# Name: x1, dtype: float64

# %%
df
# Out:
#          x1        x2         y
# 4  0.559848  0.522957  0.684363
# 0  0.666682  0.649671  0.203462
# 3  0.501939  0.425009  0.658211
# 1  0.504510  0.954037  0.716340
# 2  0.339701  0.984887  0.385465

# %%
X_df2 = df['x1']

# %%
X_df2
# Out:
# 4    0.559848
# 0    0.666682
# 3    0.501939
# 1    0.504510
# 2    0.339701
# Name: x1, dtype: float64

# %%
X_df2.iloc[0:2]
# Out:
# 4    0.559848
# 0    0.666682
# Name: x1, dtype: float64

# %%
X_df2
# Out:
# 4    0.559848
# 0    0.666682
# 3    0.501939
# 1    0.504510
# 2    0.339701
# Name: x1, dtype: float64

# %%
import pandas as pd
import numpy as np

# %%
x1 = np.random.uniform(size=5)
x2 = np.random.uniform(size=5)
y = np.random.uniform(size=5)
df = pd.DataFrame({"x1" : x1, "x2" : x2, "y" : y, "x1_x2":x1/x2})

# %%
df.head()
# Out:
#          x1     x1_x2        x2         y
# 0  0.506175  0.548931  0.922109  0.578274
# 1  0.774505  1.977260  0.391706  0.564214
# 2  0.120312  0.157910  0.761905  0.108448
# 3  0.116889  0.397712  0.293904  0.262780
# 4  0.829032  0.838994  0.988127  0.199286

# %%
df['x1_x2_x3'] = df['x1']/df['x2']

# %%
df.head()
# Out:
#          x1     x1_x2        x2         y  x1_x2_x3
# 0  0.774505  1.977260  0.391706  0.564214  1.977260
# 1  0.120312  0.157910  0.761905  0.108448  0.157910
# 2  0.829032  0.838994  0.988127  0.199286  0.838994
# 3  0.116889  0.397712  0.293904  0.262780  0.397712
# 4  0.506175  0.548931  0.922109  0.578274  0.548931

# %%
df.set_index(np.random.permutation(df.index),inplace=True)
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#          x1     x1_x2        x2         y  x1_x2_x3
# 0  0.506175  0.548931  0.922109  0.578274  0.548931
# 1  0.120312  0.157910  0.761905  0.108448  0.157910
# 2  0.774505  1.977260  0.391706  0.564214  1.977260
# 3  0.829032  0.838994  0.988127  0.199286  0.838994
# 4  0.116889  0.397712  0.293904  0.262780  0.397712

# %%
df.set_index(np.random.permutation(df.index),inplace=True)
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#          x1     x1_x2        x2         y  x1_x2_x3
# 0  0.120312  0.157910  0.761905  0.108448  0.157910
# 1  0.829032  0.838994  0.988127  0.199286  0.838994
# 2  0.774505  1.977260  0.391706  0.564214  1.977260
# 3  0.116889  0.397712  0.293904  0.262780  0.397712
# 4  0.506175  0.548931  0.922109  0.578274  0.548931

# %%
df = pd.read_hdf('/scratch/nchernya/HHbbgg/ttbar_morevariables/ttbar_full_jobs_RegressionPerJet_heppy_energyRings_forTraining_0_full.hd5',columns=None
            )

# %%
df.shape[0]
# Out:
# 733486

# %%
df['isEle'] = np.zeros( (df.shape[0],1) )

# %%
a = df.loc[abs(df.Jet_leptonPdgId) == 13, 'isEle'] = 1

# %%
df[['Jet_leptonPdgId','isEle']]
# Out:
#          Jet_leptonPdgId  isEle
# 1                  -99.0    0.0
# 5                   11.0    0.0
# 8                  -99.0    0.0
# 9                  -99.0    0.0
# 13                 -11.0    0.0
# 14                  13.0    1.0
# 17                 -99.0    0.0
# 19                 -99.0    0.0
# 26                 -99.0    0.0
# 27                 -99.0    0.0
# 28                 -99.0    0.0
# 31                 -99.0    0.0
# 34                 -99.0    0.0
# 37                 -99.0    0.0
# 43                 -99.0    0.0
# 44                 -99.0    0.0
# 47                 -99.0    0.0
# 50                 -11.0    0.0
# 52                 -99.0    0.0
# 56                  13.0    1.0
# 57                  13.0    1.0
# 64                 -13.0    1.0
# 67                 -99.0    0.0
# 68                 -99.0    0.0
# 72                 -99.0    0.0
# 74                 -99.0    0.0
# 77                  13.0    1.0
# 81                 -99.0    0.0
# ...

# %%
df['hasptD'] = df['Jet_ptd']
df['hasptD']
# Out:
# 1           0.335216
# 5         -20.000000
# 8           0.352375
# 9           0.298767
# 13          0.665056
# 14          0.390830
# 17          0.487779
# 19          0.419425
# 26          0.741840
# 27          0.388123
# 28          0.262707
# 31          0.488510
# 34        -20.000000
# 37          0.269335
# 43          0.497806
# 44          0.663655
# 47          0.587784
# 50          0.379507
# 52          0.502417
# 56          0.458858
# 57          0.442488
# 64          0.386749
# 67          0.393604
# 68          0.538072
# 72          0.414556
# 74          0.318604
# 77          0.420911
# 81          0.581246
# 85          0.522125
# 88          0.325756
#              ...
# 2756195     0.372261
# 2756197     0.541623
# 2756200     0.354091
# 2756205     0.338175
# 2756206     0.436130
# 2756210     0.413004
# 2756212     0.250481
# 2756216   -20.000000
# 2756220     0.353575
# 2756221     0.361626
# 2756227     0.291755
# 2756233     0.333050
# ...

# %%
df.loc[df.Jet_ptd < 0 ,'hasptD' ] = df[ df['Jet_ptd'] > 0 ]['Jet_ptd'].median()

# %%
df['hasptD']
# Out:
# 1          0.335216
# 5          0.389398
# 8          0.352375
# 9          0.298767
# 13         0.665056
# 14         0.390830
# 17         0.487779
# 19         0.419425
# 26         0.741840
# 27         0.388123
# 28         0.262707
# 31         0.488510
# 34         0.389398
# 37         0.269335
# 43         0.497806
# 44         0.663655
# 47         0.587784
# 50         0.379507
# 52         0.502417
# 56         0.458858
# 57         0.442488
# 64         0.386749
# 67         0.393604
# 68         0.538072
# 72         0.414556
# 74         0.318604
# 77         0.420911
# 81         0.581246
# 85         0.522125
# 88         0.325756
#              ...
# 2756195    0.372261
# 2756197    0.541623
# 2756200    0.354091
# 2756205    0.338175
# 2756206    0.436130
# 2756210    0.413004
# 2756212    0.250481
# 2756216    0.389398
# 2756220    0.353575
# 2756221    0.361626
# 2756227    0.291755
# 2756233    0.333050
# 2756234    0.335731
# 2756237    0.269457
# ...

# %%
# Out:
# 0.38939791917800903

# %%
df.loc[df.Jet_leptonPtRelInv < 0 ,'Jet_leptonPtRelInv' ] = 0

# %%
df[['Jet_leptonPtRelInv']]
# Out:
#          Jet_leptonPtRelInv
# 1                  0.000000
# 5                  1.476298
# 8                  0.000000
# 9                  0.000000
# 13                 3.034136
# 14                 3.709053
# 17                 0.000000
# 19                 0.000000
# 26                 0.000000
# 27                 0.000000
# 28                 0.000000
# 31                 0.000000
# 34                 0.000000
# 37                 0.000000
# 43                 0.000000
# 44                 0.000000
# 47                 0.000000
# 50                 4.243289
# 52                 0.000000
# 56                 1.040003
# 57                12.556256
# 64                 7.321638
# 67                 0.000000
# 68                 0.000000
# 72                 0.000000
# 74                 0.000000
# 77                 7.148552
# 81                 0.000000
# 85                 0.000000
# 88                 0.000000
# ...                     ...
# 2756195            0.000000
# ...

# %%
data = pd.read_hdf('/scratch/nchernya/HHbbgg/ttbar_morevariables/ttbar_full_jobs_RegressionPerJet_heppy_energyRings_forTraining_con020_morevar.hd5',columns=None)

# %%
data[['Jet_leptonPdgId','isEle','isMu','isOther']]
# Out:
#         Jet_leptonPdgId  isEle  isMu  isOther
# 0                 -99.0    0.0   0.0      1.0
# 1                  11.0    1.0   0.0      0.0
# 2                 -99.0    0.0   0.0      1.0
# 3                 -99.0    0.0   0.0      1.0
# 4                 -11.0    1.0   0.0      0.0
# 5                  13.0    0.0   1.0      0.0
# 6                 -99.0    0.0   0.0      1.0
# 7                 -99.0    0.0   0.0      1.0
# 8                 -99.0    0.0   0.0      1.0
# 9                 -99.0    0.0   0.0      1.0
# 10                -99.0    0.0   0.0      1.0
# 11                -99.0    0.0   0.0      1.0
# 12                -99.0    0.0   0.0      1.0
# 13                -99.0    0.0   0.0      1.0
# 14                -99.0    0.0   0.0      1.0
# 15                -99.0    0.0   0.0      1.0
# 16                -99.0    0.0   0.0      1.0
# 17                -11.0    1.0   0.0      0.0
# 18                -99.0    0.0   0.0      1.0
# ...

# %%
data.query('Jet_leptonPdgId!=13 & Jet_leptonPdgId!=-13 & Jet_leptonPdgId!=11 & Jet_leptonPdgId!=-11 & Jet_leptonPdgId!=-99')
# Out:
# Empty DataFrame
# ...

# %%
data[['Jet_ptd','Jet_withPtd']]
# Out:
#           Jet_ptd  Jet_withPtd
# 0        0.335216     0.335216
# 1      -20.000000     0.389398
# 2        0.352375     0.352375
# 3        0.298767     0.298767
# 4        0.665056     0.665056
# 5        0.390830     0.390830
# 6        0.487779     0.487779
# 7        0.419425     0.419425
# 8        0.741840     0.741840
# 9        0.388123     0.388123
# 10       0.262707     0.262707
# 11       0.488510     0.488510
# 12     -20.000000     0.389398
# 13       0.269335     0.269335
# 14       0.497806     0.497806
# 15       0.663655     0.663655
# 16       0.587784     0.587784
# 17       0.379507     0.379507
# 18       0.502417     0.502417
# 19       0.458858     0.458858
# 20       0.442488     0.442488
# 21       0.386749     0.386749
# 22       0.393604     0.393604
# 23       0.538072     0.538072
# 24       0.414556     0.414556
# 25       0.318604     0.318604
# 26       0.420911     0.420911
# 27       0.581246     0.581246
# 28       0.522125     0.522125
# ...

# %%
features_hbb = 'Jet_pt,Jet_eta,nPVs,Jet_mt,Jet_leadTrackPt,Jet_leptonPtRel,Jet_leptonPt,Jet_leptonDeltaR,Jet_neHEF,Jet_neEmEF,Jet_vtxPt,Jet_vtxMass,Jet_vtx3dL,Jet_vtxNtrk,Jet_vtx3deL'.split(',')

# %%
features_us = 'Jet_pt,Jet_eta,rho,Jet_mt,Jet_leadTrackPt,Jet_leptonPtRel,Jet_leptonDeltaR,Jet_neHEF,Jet_neEmEF,Jet_vtxPt,Jet_vtxMass,Jet_vtx3dL,Jet_vtxNtrk,Jet_vtx3deL,Jet_numDaughters_pt03,Jet_energyRing_dR0_em_Jet_rawEnergy,Jet_energyRing_dR1_em_Jet_rawEnergy,Jet_energyRing_dR2_em_Jet_rawEnergy,Jet_energyRing_dR3_em_Jet_rawEnergy,Jet_energyRing_dR4_em_Jet_rawEnergy,Jet_energyRing_dR0_neut_Jet_rawEnergy,Jet_energyRing_dR1_neut_Jet_rawEnergy,Jet_energyRing_dR2_neut_Jet_rawEnergy,Jet_energyRing_dR3_neut_Jet_rawEnergy,Jet_energyRing_dR4_neut_Jet_rawEnergy,Jet_energyRing_dR0_ch_Jet_rawEnergy,Jet_energyRing_dR1_ch_Jet_rawEnergy,Jet_energyRing_dR2_ch_Jet_rawEnergy,Jet_energyRing_dR3_ch_Jet_rawEnergy,Jet_energyRing_dR4_ch_Jet_rawEnergy,Jet_energyRing_dR0_mu_Jet_rawEnergy,Jet_energyRing_dR1_mu_Jet_rawEnergy,Jet_energyRing_dR2_mu_Jet_rawEnergy,Jet_energyRing_dR3_mu_Jet_rawEnergy,Jet_energyRing_dR4_mu_Jet_rawEnergy'.split(',')

# %%
features_pisa = 'Jet_pt,Jet_eta,nPVs,Jet_mt,Jet_leadTrackPt,Jet_leptonPtRel,Jet_leptonPt,Jet_leptonDeltaR,Jet_neHEF,Jet_neEmEF,Jet_vtxPt,Jet_vtxMass,Jet_vtx3dL,Jet_vtxNtrk,Jet_vtx3deL,Jet_leptonPdgId,Jet_corr_JEC,Jet_mass,Jet_ptd,Jet_leptonPtRelInv,Jet_chHEF,Jet_chEmEF'.split(',')

# %%
data[features_us]
# Out:
#               Jet_pt   Jet_eta        rho      Jet_mt  Jet_leadTrackPt  \
# 0          65.291756 -0.604846  11.751464   66.256012        14.210938
# 1          17.434765 -1.741531  11.751464   17.746229         6.664062
# 2          46.753475 -0.429504   7.653327   47.129597         5.664062
# 3          36.657639 -0.055479   7.653327   37.261658         4.816406
# 4         100.904572 -1.237152  14.027356  101.875648        55.656250
# 5          46.282543 -1.460964  14.027356   47.140816         9.390625
# 6         272.123047 -0.594620  12.156137  274.141235        87.562500
# 7         119.211258 -0.415559  12.156137  119.946442        39.812500
# 8          56.314056  2.442108   9.794931   56.565659        13.804688
# 9          89.272141 -2.025109  11.109515   90.030441        15.835938
# 10         42.171024  0.010261  11.109515   43.233101         3.894531
# 11        105.648270  2.373206  15.126159  106.151222        10.554688
# ...

# %%
data[features_hbb]
# Out:
#               Jet_pt   Jet_eta  nPVs      Jet_mt  Jet_leadTrackPt  \
# 0          65.291756 -0.604846  11.0   66.256012        14.210938
# 1          17.434765 -1.741531  11.0   17.746229         6.664062
# 2          46.753475 -0.429504  15.0   47.129597         5.664062
# 3          36.657639 -0.055479  15.0   37.261658         4.816406
# 4         100.904572 -1.237152  14.0  101.875648        55.656250
# 5          46.282543 -1.460964  14.0   47.140816         9.390625
# 6         272.123047 -0.594620  20.0  274.141235        87.562500
# 7         119.211258 -0.415559  20.0  119.946442        39.812500
# 8          56.314056  2.442108  15.0   56.565659        13.804688
# 9          89.272141 -2.025109  13.0   90.030441        15.835938
# 10         42.171024  0.010261  13.0   43.233101         3.894531
# 11        105.648270  2.373206  18.0  106.151222        10.554688
# 12         17.878185 -0.197119  18.0   18.490688         5.746094
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
data[features_pisa]
# Out:
#               Jet_pt   Jet_eta  nPVs      Jet_mt  Jet_leadTrackPt  \
# 0          65.291756 -0.604846  11.0   66.256012        14.210938
# 1          17.434765 -1.741531  11.0   17.746229         6.664062
# 2          46.753475 -0.429504  15.0   47.129597         5.664062
# 3          36.657639 -0.055479  15.0   37.261658         4.816406
# 4         100.904572 -1.237152  14.0  101.875648        55.656250
# 5          46.282543 -1.460964  14.0   47.140816         9.390625
# 6         272.123047 -0.594620  20.0  274.141235        87.562500
# 7         119.211258 -0.415559  20.0  119.946442        39.812500
# 8          56.314056  2.442108  15.0   56.565659        13.804688
# 9          89.272141 -2.025109  13.0   90.030441        15.835938
# 10         42.171024  0.010261  13.0   43.233101         3.894531
# 11        105.648270  2.373206  18.0  106.151222        10.554688
# 12         17.878185 -0.197119  18.0   18.490688         5.746094
# ...

# %%
features_pisa = 'Jet_pt,Jet_eta,nPVs,Jet_mt,Jet_leadTrackPt,Jet_leptonPtRel,Jet_leptonPt,Jet_leptonDeltaR,Jet_neHEF,Jet_neEmEF,Jet_vtxPt,Jet_vtxMass,Jet_vtx3dL,Jet_vtxNtrk,Jet_vtx3deL,isEle,isMu,isOther,Jet_corr_JEC,Jet_mass,Jet_withPtd,Jet_leptonPtRelInv,Jet_chHEF,Jet_chEmEF'.split(',')

# %%
data[features_pisa]
# Out:
#               Jet_pt   Jet_eta  nPVs      Jet_mt  Jet_leadTrackPt  \
# 0          65.291756 -0.604846  11.0   66.256012        14.210938
# 1          17.434765 -1.741531  11.0   17.746229         6.664062
# 2          46.753475 -0.429504  15.0   47.129597         5.664062
# 3          36.657639 -0.055479  15.0   37.261658         4.816406
# 4         100.904572 -1.237152  14.0  101.875648        55.656250
# 5          46.282543 -1.460964  14.0   47.140816         9.390625
# 6         272.123047 -0.594620  20.0  274.141235        87.562500
# 7         119.211258 -0.415559  20.0  119.946442        39.812500
# 8          56.314056  2.442108  15.0   56.565659        13.804688
# 9          89.272141 -2.025109  13.0   90.030441        15.835938
# 10         42.171024  0.010261  13.0   43.233101         3.894531
# 11        105.648270  2.373206  18.0  106.151222        10.554688
# 12         17.878185 -0.197119  18.0   18.490688         5.746094
# ...

# %%
chech = pd.read_hdf('/scratch/nchernya/HHbbgg/ttbar_morevariables/ttbar_full_jobs_RegressionPerJet_heppy_energyRings_forTraining_con134137_morevar.hd5',columns=None)

# %%
chech.shape[0]
# Out:
# 1806261

# %%
chech = pd.read_hdf('/scratch/nchernya/HHbbgg/ttbar_morevariables/ttbar_full_RegressionPerJet_heppy_energyRings_validation_morevar.hd5',columns=None)

# %%
chech.shape[0]
# Out:
# 3096617

# %%
path='/scratch/nchernya/HHbbgg/ttbar_full_hd5/final0/'
df = pd.read_hdf(path+'ttbar_full_RegressionPerJet_heppy_energyRings_testing.hd5',columns=None)

# %%
df.shape[0]
# Out:
# 2364760

# %%
path='/scratch/nchernya/HHbbgg/ttbar_full_hd5/final0/'
df = pd.read_hdf(path+'ttbar_full_RegressionPerJet_heppy_energyRings_validation.hd5',columns=None)
df.shape[0]
# Out:
# 2279919

# %%
1806261+3096617
# Out:
# 4902878

# %%
2279919+2364760
# Out:
# 4644679

# %%
df[['Jet_pt','Jet_mt','Jet_corr_JEC']][0:5]
# Out:
#       Jet_pt     Jet_mt  Jet_corr_JEC
# 0  81.475090  82.467316      0.996798
# 1  44.343071  44.970196      0.967555
# 2  85.200333  85.926659      1.067876
# 3  64.640327  66.089706      1.123492
# 4  50.463623  50.963627      1.019125

# %%
df['Jet_pt_raw'] = df['Jet_pt']*df['Jet_rawEnergy']/df['Jet_e']
df['Jet_mt_raw'] = df['Jet_mt']*df['Jet_rawEnergy']/df['Jet_e']

# %%
df[['Jet_pt','Jet_pt_raw','Jet_mt','Jet_mt_raw','Jet_corr_JEC']][0:5]
# Out:
#       Jet_pt  Jet_pt_raw     Jet_mt  Jet_mt_raw  Jet_corr_JEC
# 0  81.475090   80.528656  82.467316   81.509354      0.996798
# 1  44.343071   46.682404  44.970196   47.342613      0.967555
# 2  85.200333   79.218163  85.926659   79.893494      1.067876
# 3  64.640327   57.275555  66.089706   58.559807      1.123492
# 4  50.463623   49.634647  50.963627   50.126434      1.019125

# %%
# Out:
#      Jet_pt  Jet_pt_raw    Jet_mt  Jet_mt_raw  Jet_corr_JEC
# 0  0.879130   80.528656  0.889836   81.509354      0.996798
# 1  0.939383   46.682404  0.952668   47.342613      0.967555
# 2  0.675336   79.218163  0.681094   79.893494      1.067876
# 3  0.415382   57.275555  0.424696   58.559807      1.123492
# 4  0.813928   49.634647  0.821993   50.126434      1.019125

# %%
# Out:
# ['Jet_pt_original', 'Jet_mt']

# %%
path='/scratch/nchernya/HHbbgg/ttbar_morevariables/'
df = pd.read_hdf(path+'ttbar_full_RegressionPerJet_heppy_energyRings_validation_morevar.hd5',columns=None)
df.shape[0]
df[['Jet_pt','Jet_mass','Jet_eta','Jet_phi','Jet_corr_JEC']][0:1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-c52a01ffff57> in <module>()
#       2 df = pd.read_hdf(path+'ttbar_full_RegressionPerJet_heppy_energyRings_validation_morevar.hd5',columns=None)
#       3 df.shape[0]
# ----> 4 df[['Jet_pt','Jet_mass','Jet_eta','Jet_phi','Jet_corr_JEC']][0:1]
#
# /mnt/t3nfs01/data01/shome/nchernya/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /mnt/t3nfs01/data01/shome/nchernya/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
# ...

# %%
d = pd.DataFrame( {'\eta':[1,2,4],'a':[1.1,2.1,4.1],'b':[1.2,2.2,4.2] }  )

# %%
import matplotlib.pyplot as plt

# %%
ax = d.plot.scatter(x='a',y='b')
d.plot.scatter(x='b',y='a',color='r',ax=ax)

plt.show()
